# %% [markdown]
# # Exploratory Data Analysis - NYC Taxi Dataset
#
# This notebook performs EDA on the NYC Yellow Taxi trip records.

# %%
import os
import sys
sys.path.append('..')
from src.data_loader import load_raw_data
from src.eda_tools import run_eda

df = load_raw_data()
print(f"Total Records: {df.count()}")

# %%
run_eda()
